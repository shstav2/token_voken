# %%
import sys
sys.path.append('/home/stav/Projects/token_voken/')
sys.executable
# Out:
# '/usr/bin/python3'

# %%
from IPython.display import Image, display
import matplotlib.pyplot as plt

from src.img_utils.reader import get_tensor_image
from src.common.constants import OLIVER_FACE_PATH
from src.common.display_utils import printmd, display_faces

# %%
def show(path):
    display(Image(path))

def show_faces(path_faces):
    display(Image(path))

# %%
OLIVER_FACE_PATH
# Out:
# '/home/stav/Data/Sample/oliver/face.jpg'

# %%
show(OLIVER_FACE_PATH)

# %%
show('/home/stav/Data/PATS_DATA/Videos/oliver/1Y1ya-yF35g/100984/Faces/00097.jpg')

# %% [markdown]
# ### Case vU8dCYocuyI#216641#43

# %%
display_faces('/home/stav/Data/PATS_DATA/Videos/oliver/vU8dCYocuyI/216641/FacesAll/00043/')
# Out:
# **(1920 × 1080) /home/stav/Data/PATS_DATA/Videos/oliver/vU8dCYocuyI/216641/FacesAll/00043/annotated_faces.jpg**
# **(224 × 224) /home/stav/Data/PATS_DATA/Videos/oliver/vU8dCYocuyI/216641/FacesAll/00043/face_0.jpg**
# **(224 × 224) /home/stav/Data/PATS_DATA/Videos/oliver/vU8dCYocuyI/216641/FacesAll/00043/face_1.jpg**

# %%
display_faces('/home/stav/Data/PATS_DATA/Videos/oliver/vU8dCYocuyI/216641/FacesAll/00102/')
# Out:
# **(1920 × 1080) /home/stav/Data/PATS_DATA/Videos/oliver/vU8dCYocuyI/216641/FacesAll/00102/annotated_faces.jpg**
# **(224 × 224) /home/stav/Data/PATS_DATA/Videos/oliver/vU8dCYocuyI/216641/FacesAll/00102/face_0.jpg**
# **(224 × 224) /home/stav/Data/PATS_DATA/Videos/oliver/vU8dCYocuyI/216641/FacesAll/00102/face_1.jpg**

# %%
display_faces('/home/stav/Data/PATS_DATA/Videos/oliver/vU8dCYocuyI/216641/FacesAll/00076/')
# Out:
# **(1920 × 1080) /home/stav/Data/PATS_DATA/Videos/oliver/vU8dCYocuyI/216641/FacesAll/00076/annotated_faces.jpg**
# **(224 × 224) /home/stav/Data/PATS_DATA/Videos/oliver/vU8dCYocuyI/216641/FacesAll/00076/face_0.jpg**
# **(224 × 224) /home/stav/Data/PATS_DATA/Videos/oliver/vU8dCYocuyI/216641/FacesAll/00076/face_1.jpg**

# %%
display_faces('/home/stav/Data/PATS_DATA/Videos/oliver/vU8dCYocuyI/216641/FacesAll/00100/')
# Out:
# **(1920 × 1080) /home/stav/Data/PATS_DATA/Videos/oliver/vU8dCYocuyI/216641/FacesAll/00100/annotated_faces.jpg**
# **(224 × 224) /home/stav/Data/PATS_DATA/Videos/oliver/vU8dCYocuyI/216641/FacesAll/00100/face_0.jpg**
# **(224 × 224) /home/stav/Data/PATS_DATA/Videos/oliver/vU8dCYocuyI/216641/FacesAll/00100/face_1.jpg**

# %%
show('/home/stav/Data/PATS_DATA/Videos/oliver/vU8dCYocuyI/216641/FacesAll/00100/face_0.jpg')

# %% [markdown]
# ### 80

# %%
display_faces('/home/stav/Data/PATS_DATA/Videos/oliver/vU8dCYocuyI/216641/FacesAll/00080')
# Out:
# **(1920 × 1080) /home/stav/Data/PATS_DATA/Videos/oliver/vU8dCYocuyI/216641/FacesAll/00080/annotated_faces.jpg**
# **(224 × 224) /home/stav/Data/PATS_DATA/Videos/oliver/vU8dCYocuyI/216641/FacesAll/00080/face_0.jpg**
# **(224 × 224) /home/stav/Data/PATS_DATA/Videos/oliver/vU8dCYocuyI/216641/FacesAll/00080/face_1.jpg**

# %%
display_faces('/home/stav/Data/PATS_DATA/Videos/oliver/vU8dCYocuyI/216641_delete/FacesAll/FacesAll/00100')
# Out:
# **(224 × 224) /home/stav/Data/PATS_DATA/Videos/oliver/vU8dCYocuyI/216641_delete/FacesAll/FacesAll/00100/face_3.jpg**
# **(224 × 224) /home/stav/Data/PATS_DATA/Videos/oliver/vU8dCYocuyI/216641_delete/FacesAll/FacesAll/00100/face_0.jpg**
# **(224 × 224) /home/stav/Data/PATS_DATA/Videos/oliver/vU8dCYocuyI/216641_delete/FacesAll/FacesAll/00100/face_1.jpg**

# %%
dist = {'/home/stav/Data/PATS_DATA/Videos/oliver/vU8dCYocuyI/216641_delete/FacesAll/FacesAll/00100/face_0.jpg': (0.09983899055944431, 0.09757489), '/home/stav/Data/PATS_DATA/Videos/oliver/vU8dCYocuyI/216641_delete/FacesAll/FacesAll/00100/face_1.jpg': (0.07435343456157188, 0.05431591), '/home/stav/Data/PATS_DATA/Videos/oliver/vU8dCYocuyI/216641_delete/FacesAll/FacesAll/00100/face_3.jpg': (None, 0.0)}

# %%
import ipyplot
import matplotlib.image as mpimg

# %%
img0 = '/home/stav/Data/PATS_DATA/Videos/oliver/vU8dCYocuyI/216635/FacesAll/00128/face_0.jpg'
img1 = '/home/stav/Data/PATS_DATA/Videos/oliver/vU8dCYocuyI/216635/FacesAll/00128/face_1.jpg'
img3 =  '/home/stav/Data/Sample/oliver/face.jpg'

# %%
dist = ['Euclidian: 0.0602, Cosine: 0.0783', 'Euclidian: 0.0551, Cosine: 0.0749']
for i, face_img in enumerate([img0, img1]):
    ipyplot.plot_images(list(map(mpimg.imread, [face_img, img3])),
                        labels=[f'Detected Face {i}', 'Base Image'],
                        max_images=2, img_width=224)
    printmd(f'**distance**: {dist[i]}')
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-awJvsSv997eUT2mDjBfdNL {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-awJvsSv997eUT2mDjBfdNL {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-awJvsSv997eUT2mDjBfdNL {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-awJvsSv997eUT2mDjBfdNL:checked ~ #ipyplot-html-viewer-textarea-awJvsSv997eUT2mDjBfdNL {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-awJvsSv997eUT2mDjBfdNL:checked + #ipyplot-html-viewer-label-awJvsSv997eUT2mDjBfdNL:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-awJvsSv997eUT2mDjBfdNL">
#         <label id="ipyplot-html-viewer-label-awJvsSv997eUT2mDjBfdNL" for="ipyplot-html-viewer-toggle-awJvsSv997eUT2mDjBfdNL">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-awJvsSv997eUT2mDjBfdNL" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-kWPo9K9bboStCL9f8cXjXo {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-kWPo9K9bboStCL9f8cXjXo {
#             width: 224px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-kWPo9K9bboStCL9f8cXjXo {
#             width: 224px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-kWPo9K9bboStCL9f8cXjXo span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-kWPo9K9bboStCL9f8cXjXo span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-kWPo9K9bboStCL9f8cXjXo img {
#             width: 224px;
#         }
#
#         div.ipyplot-content-div-kWPo9K9bboStCL9f8cXjXo span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-kWPo9K9bboStCL9f8cXjXo span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-kWPo9K9bboStCL9f8cXjXo]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-kWPo9K9bboStCL9f8cXjXo]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-kWPo9K9bboStCL9f8cXjXo]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-kWPo9K9bboStCL9f8cXjXo">
#     <div class="ipyplot-placeholder-div-kWPo9K9bboStCL9f8cXjXo">
#         <div id="ipyplot-content-div-kWPo9K9bboStCL9f8cXjXo-duCd9bjBgVoZQucEpLSnBV" class="ipyplot-content-div-kWPo9K9bboStCL9f8cXjXo">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Detected Face 0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-kWPo9K9bboStCL9f8cXjXo-duCd9bjBgVoZQucEpLSnBV">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-kWPo9K9bboStCL9f8cXjXo">
#         <div id="ipyplot-content-div-kWPo9K9bboStCL9f8cXjXo-Ejes26CLcPsQEDAqotVkDB" class="ipyplot-content-div-kWPo9K9bboStCL9f8cXjXo">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Base Image</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-kWPo9K9bboStCL9f8cXjXo-Ejes26CLcPsQEDAqotVkDB">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-kWPo9K9bboStCL9f8cXjXo {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-kWPo9K9bboStCL9f8cXjXo {
#             width: 224px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-kWPo9K9bboStCL9f8cXjXo {
#             width: 224px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-kWPo9K9bboStCL9f8cXjXo span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-kWPo9K9bboStCL9f8cXjXo span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-kWPo9K9bboStCL9f8cXjXo img {
#             width: 224px;
#         }
#
#         div.ipyplot-content-div-kWPo9K9bboStCL9f8cXjXo span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-kWPo9K9bboStCL9f8cXjXo span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-kWPo9K9bboStCL9f8cXjXo]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-kWPo9K9bboStCL9f8cXjXo]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-kWPo9K9bboStCL9f8cXjXo]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-kWPo9K9bboStCL9f8cXjXo">
#     <div class="ipyplot-placeholder-div-kWPo9K9bboStCL9f8cXjXo">
#         <div id="ipyplot-content-div-kWPo9K9bboStCL9f8cXjXo-duCd9bjBgVoZQucEpLSnBV" class="ipyplot-content-div-kWPo9K9bboStCL9f8cXjXo">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Detected Face 0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-kWPo9K9bboStCL9f8cXjXo-duCd9bjBgVoZQucEpLSnBV">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-kWPo9K9bboStCL9f8cXjXo">
#         <div id="ipyplot-content-div-kWPo9K9bboStCL9f8cXjXo-Ejes26CLcPsQEDAqotVkDB" class="ipyplot-content-div-kWPo9K9bboStCL9f8cXjXo">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Base Image</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-kWPo9K9bboStCL9f8cXjXo-Ejes26CLcPsQEDAqotVkDB">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
# **distance**: Euclidian: 0.0602, Cosine: 0.0783
#     <style>
#         #ipyplot-html-viewer-toggle-PJCtzAoUm2XAE3hhJyJJMW {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-PJCtzAoUm2XAE3hhJyJJMW {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-PJCtzAoUm2XAE3hhJyJJMW {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-PJCtzAoUm2XAE3hhJyJJMW:checked ~ #ipyplot-html-viewer-textarea-PJCtzAoUm2XAE3hhJyJJMW {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-PJCtzAoUm2XAE3hhJyJJMW:checked + #ipyplot-html-viewer-label-PJCtzAoUm2XAE3hhJyJJMW:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-PJCtzAoUm2XAE3hhJyJJMW">
#         <label id="ipyplot-html-viewer-label-PJCtzAoUm2XAE3hhJyJJMW" for="ipyplot-html-viewer-toggle-PJCtzAoUm2XAE3hhJyJJMW">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-